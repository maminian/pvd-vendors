# %%
# RUN THIS CELL FIRST or the notebook won't work
# !pip install geopandas
import numpy as np
import pandas as pd
import geopandas as gpd
from IPython.display import display
import matplotlib.pyplot as plt

# These help the maps display nicely in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = [30, 20]

# This line tells iPython to not display warnings.
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: geopandas in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (0.10.2)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: fiona>=1.8 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=0.25.0 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: shapely>=1.6 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: munch in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: certifi in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click>=4.0 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: click-plugins>=1.0 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: setuptools in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /Users/neo/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.0->geopandas) (1.20.3)

# %%
ri = gpd.read_file('tl_2020_44_tract')
ri
# Out:
#     STATEFP COUNTYFP TRACTCE        GEOID    NAME             NAMELSAD  MTFCC  \
# 0        44      003  021002  44003021002  210.02  Census Tract 210.02  G5020
# 1        44      003  021300  44003021300     213     Census Tract 213  G5020
# 2        44      003  021100  44003021100     211     Census Tract 211  G5020
# 3        44      003  020904  44003020904  209.04  Census Tract 209.04  G5020
# 4        44      003  020200  44003020200     202     Census Tract 202  G5020
# ..      ...      ...     ...          ...     ...                  ...    ...
# 245      44      007  010400  44007010400     104     Census Tract 104  G5020
# 246      44      007  014700  44007014700     147     Census Tract 147  G5020
# 247      44      007  001800  44007001800      18      Census Tract 18  G5020
# 248      44      007  002400  44007002400      24      Census Tract 24  G5020
# 249      44      007  001400  44007001400      14      Census Tract 14  G5020
#
#     FUNCSTAT    ALAND   AWATER     INTPTLAT      INTPTLON  \
# 0          S  2706612   472653  +41.7569676  -071.3947778
# 1          S  4168478  2578903  +41.7397743  -071.3870958
# 2          S  7158162   136612  +41.7424748  -071.4343102
# 3          S  8168014   106585  +41.6418594  -071.4776700
# 4          S  2891313   230898  +41.6995981  -071.5189090
# ..       ...      ...      ...          ...           ...
# 245        S  3166869   757660  +41.8066084  -071.3785951
# 246        S  3643516   346677  +41.7937099  -071.4635031
# 247        S  1832956     8074  +41.8157153  -071.4612431
# 248        S  3209389     5342  +41.8435523  -071.4493215
# 249        S   908656        0  +41.8063542  -071.4345619
#
#                                               geometry
# 0    POLYGON ((-71.40520 41.76761, -71.40509 41.767...
# 1    POLYGON ((-71.40817 41.73867, -71.40815 41.739...
# 2    POLYGON ((-71.45841 41.72849, -71.45827 41.728...
# 3    POLYGON ((-71.49569 41.60268, -71.49563 41.602...
# 4    POLYGON ((-71.53311 41.69533, -71.53301 41.695...
# ..                                                 ...
# 245  POLYGON ((-71.39526 41.81167, -71.39381 41.814...
# 246  POLYGON ((-71.47974 41.79685, -71.47957 41.796...
# 247  POLYGON ((-71.47088 41.82194, -71.47068 41.821...
# 248  POLYGON ((-71.46456 41.84207, -71.46353 41.842...
# 249  POLYGON ((-71.44196 41.80665, -71.44195 41.806...
#
# [250 rows x 13 columns]

# %%
pvdCounty = ri[ri.COUNTYFP=='007']
pvdCounty.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 145 entries, 59 to 249
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   STATEFP   145 non-null    object
#  1   COUNTYFP  145 non-null    object
#  2   TRACTCE   145 non-null    object
#  3   GEOID     145 non-null    object
#  4   NAME      145 non-null    object
#  5   NAMELSAD  145 non-null    object
#  6   MTFCC     145 non-null    object
#  7   FUNCSTAT  145 non-null    object
#  8   ALAND     145 non-null    int64
#  9   AWATER    145 non-null    int64
#  10  INTPTLAT  145 non-null    object
#  11  INTPTLON  145 non-null    object
#  12  geometry  145 non-null    geometry
# dtypes: geometry(1), int64(2), object(10)
# memory usage: 15.9+ KB

# %%
pvdCounty['NAME']= pvdCounty['NAME'].astype(str).astype(float)

# %%
pvd = pvdCounty[pvdCounty.NAME < 40]
# Out:
# <GeometryArray>
# [<shapely.geometry.point.Point object at 0x7f8d19de8970>]
# Length: 1, dtype: geometry

# %%
ax = plt.subplot() 
gpd.points_from_xy([41.8268], [71.], crs="EPSG:4326")
pvd.plot(legend=True,ax=ax)
plt.show()

# %%
# !pip install altair
# !pip install gpdvega
# !pip install altair vega_datasets

# %%
data = [[41.824457494172485, -71.40706551534042], ]
 
#     41.824457494172485, -71.40706551534042
# Create the pandas DataFrame
current = pd.DataFrame(data, columns=['lat', 'long'])
 
# print dataframe.
current
# Out:
#          lat       long
# 0  41.824457 -71.407066

# %%
import altair as alt
import gpdvega 




bg = alt.Chart(pvd).mark_geoshape(
).encode( 
  
).properties( 
    width=500,
    height=300
)


points = alt.Chart(current).mark_circle( color='red').encode(
    latitude='lat',
    longitude='long',
    size=alt.value(100),


)

bg + points
# Out:
# alt.LayerChart(...)

# %%
pvd
# Out:
#     STATEFP COUNTYFP TRACTCE        GEOID   NAME            NAMELSAD  MTFCC  \
# 90       44      007  002101  44007002101  21.01  Census Tract 21.01  G5020
# 91       44      007  002102  44007002102  21.02  Census Tract 21.02  G5020
# 119      44      007  003601  44007003601  36.01  Census Tract 36.01  G5020
# 127      44      007  001700  44007001700  17.00     Census Tract 17  G5020
# 128      44      007  003200  44007003200  32.00     Census Tract 32  G5020
# 159      44      007  002000  44007002000  20.00     Census Tract 20  G5020
# 162      44      007  000101  44007000101   1.01   Census Tract 1.01  G5020
# 168      44      007  000200  44007000200   2.00      Census Tract 2  G5020
# 169      44      007  000400  44007000400   4.00      Census Tract 4  G5020
# 170      44      007  000102  44007000102   1.02   Census Tract 1.02  G5020
# 171      44      007  000500  44007000500   5.00      Census Tract 5  G5020
# 172      44      007  000600  44007000600   6.00      Census Tract 6  G5020
# 173      44      007  000700  44007000700   7.00      Census Tract 7  G5020
# 174      44      007  000800  44007000800   8.00      Census Tract 8  G5020
# 175      44      007  000900  44007000900   9.00      Census Tract 9  G5020
# 176      44      007  001000  44007001000  10.00     Census Tract 10  G5020
# 177      44      007  001100  44007001100  11.00     Census Tract 11  G5020
# 178      44      007  001200  44007001200  12.00     Census Tract 12  G5020
# 179      44      007  001300  44007001300  13.00     Census Tract 13  G5020
# 180      44      007  001500  44007001500  15.00     Census Tract 15  G5020
# 182      44      007  001900  44007001900  19.00     Census Tract 19  G5020
# 183      44      007  002200  44007002200  22.00     Census Tract 22  G5020
# 184      44      007  002300  44007002300  23.00     Census Tract 23  G5020
# 185      44      007  002500  44007002500  25.00     Census Tract 25  G5020
# 186      44      007  002600  44007002600  26.00     Census Tract 26  G5020
# 205        S   568205     5496  +41.8516944  -071.4393258
# 244        S  2632365    58298  +41.8512322  -071.4185455
# 247        S  1832956     8074  +41.8157153  -071.4612431
# 248        S  3209389     5342  +41.8435523  -071.4493215
# 249        S   908656        0  +41.8063542  -071.4345619
#
#                                               geometry
# 90   POLYGON ((-71.45357 41.83583, -71.45320 41.835...
# 91   POLYGON ((-71.45699 41.82618, -71.45698 41.826...
# 119  POLYGON ((-71.40147 41.83482, -71.40073 41.834...
# 127  POLYGON ((-71.46484 41.80595, -71.46474 41.806...
# 128  POLYGON ((-71.40797 41.84201, -71.40779 41.842...
# 159  POLYGON ((-71.47248 41.83436, -71.47242 41.834...
# 162  POLYGON ((-71.40485 41.79640, -71.40457 41.796...
# 168  POLYGON ((-71.42643 41.79505, -71.42641 41.795...
# 169  POLYGON ((-71.42100 41.80977, -71.42086 41.810...
# 170  POLYGON ((-71.42381 41.77727, -71.42276 41.780...
# 171  POLYGON ((-71.41742 41.80043, -71.41642 41.800...
# 172  POLYGON ((-71.41529 41.81697, -71.41527 41.816...
# 173  POLYGON ((-71.42233 41.81741, -71.42200 41.817...
# 174  POLYGON ((-71.42016 41.82202, -71.42015 41.822...
# 175  POLYGON ((-71.43364 41.82422, -71.43354 41.824...
# 176  POLYGON ((-71.43953 41.81596, -71.43942 41.816...
# 177  POLYGON ((-71.43177 41.82068, -71.43050 41.820...
# 178  POLYGON ((-71.43133 41.81659, -71.43048 41.816...
# 179  POLYGON ((-71.44063 41.81029, -71.44059 41.810...
# 180  POLYGON ((-71.43994 41.80342, -71.43987 41.803...
# 182  POLYGON ((-71.45634 41.82210, -71.45615 41.822...
# 183  POLYGON ((-71.44453 41.83245, -71.44389 41.832...
# 184  POLYGON ((-71.44515 41.84259, -71.44421 41.842...
# 185  POLYGON ((-71.43943 41.82475, -71.43940 41.824...
# 186  POLYGON ((-71.43042 41.83633, -71.43007 41.837...
# 187  POLYGON ((-71.43303 41.84452, -71.43300 41.844...
# 189  POLYGON ((-71.41745 41.83201, -71.41715 41.832...
# 190  POLYGON ((-71.41122 41.84823, -71.41122 41.848...
# 191  POLYGON ((-71.40157 41.83571, -71.40154 41.835...
# 192  POLYGON ((-71.39430 41.83348, -71.39329 41.833...
# 193  POLYGON ((-71.40973 41.82891, -71.40917 41.828...
# 194  POLYGON ((-71.40659 41.82280, -71.40650 41.822...
# 199  POLYGON ((-71.43173 41.80057, -71.43171 41.800...
# 200  POLYGON ((-71.44299 41.85656, -71.44235 41.856...
# 201  POLYGON ((-71.45578 41.81526, -71.45389 41.815...
# 202  POLYGON ((-71.45541 41.81321, -71.45440 41.813...
# 204  POLYGON ((-71.42652 41.80024, -71.42651 41.800...
# 205  POLYGON ((-71.44669 41.85405, -71.44628 41.854...
# 244  POLYGON ((-71.42991 41.86125, -71.42976 41.861...
# 247  POLYGON ((-71.47088 41.82194, -71.47068 41.821...
# 248  POLYGON ((-71.46456 41.84207, -71.46353 41.842...
# 249  POLYGON ((-71.44196 41.80665, -71.44195 41.806...
